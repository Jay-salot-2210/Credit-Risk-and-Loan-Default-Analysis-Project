# %% [markdown]
# # Real Data Processing
#
# Loads raw Lending Club data, applies feature engineering, and saves processed dataset.

# %%
import sys
import os
import pandas as pd

sys.path.append(os.path.abspath('../src'))
from data_utils import load_data
from features import create_features

# %%
raw_path = '../data/raw/LendingClub_data.csv'
print(f"Loading {raw_path}...")
df_raw = load_data(raw_path)
print(f"Raw shape: {df_raw.shape}")
# Out:
# Loading ../data/raw/LendingClub_data.csv...
# Raw shape: (39717, 111)

# %%
print("Creating features...")
df_clean = create_features(df_raw)
print(f"Processed shape: {df_clean.shape}")
print("Columns:", df_clean.columns.tolist())
# Out:
# Creating features...
# Processed shape: (38577, 137)
# ...

# %%
output_path = '../data/processed/cleaned_data.csv'
os.makedirs(os.path.dirname(output_path), exist_ok=True)
df_processed.to_csv("../data/processed/cleaned_loans.csv", index=False)
print(f"Saved to {output_path}")
# Out:
# Saved to ../data/processed/cleaned_data.csv
